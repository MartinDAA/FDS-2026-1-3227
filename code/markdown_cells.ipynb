# %% [markdown]
# ## CASO DE NEGOCIO:
#
# Lo que se busca resolver o encontrar con este análisis son las tendencias de los videos de Youtube que
# son publicados en Alemania
#
# ## OBJETIVOS DEL PROYECTO:
#
#  - El objeto del proyecto es analizar el data set de videos que son tendencia en el país de Alemania donde nos encargaremos de organizar y limpiar
#    los datos que sean necesarios para resolver el caso de negocio que planteamos.
#
#
# ## OBJETIVOS DE DATA SCIENCE
#
# - La meta de nuestro análisis es visualizar de manera gráfica la cantidad de visitas que tiene los videos de cada estado de Alemania.
#
# - Crear un modelo que pueda categorizar el número de visitas que tiene cada estado tomando en cuenta el número de vistas del video y del lugar
#    donde se publicó, categorizar los videos que tiene más "me gustas" y las que tienen más "no me gustas", etc.
#
# - Lograr que se cumplan todos los requerimientos planteados para este proyecto.
#
# - Para este trabajo se eligió como variable dependiente el "número de visitas (views)", por ser una variable cuyo valor es el que llama
#    más la atención de la gente que busca videos.
#
# - Para este trabajo se eligió variables independientes como: latitud-longitud/Estado en el que se publicó, título del canal, tags/categoría id, likes/dislikes
#
#
#
# ## COMPRENSIÓN DE LOS DATOS
#
# [Placeholder]
#
# ## DESCRIPCIÓN DEL DATASET:
#
# El dataset que estamos usando para este trabajo contiene datos de los videos con más tendencia que provienen de Alemania, donde cuenta con
# valores çomo el número de visitas del video, likes, dislikes, estado en el que se publicó,etc.

# %%
import pandas as pd

# %%
df = pd.read_csv("DEvideos_cc50_202101.csv")

# %%
df['category_id']
# Out:
# 0        24
# 1        23
# 2        24
# 3        27
# 4        24
#          ..
# 40835    20
# 40836    24
# 40837    24
# 40838    20
# 40839    23
# Name: category_id, Length: 40840, dtype: int64

# %% [markdown]
# ## Recolectar los datos iniciales

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %% [markdown]
# ## DESCRIPCIÓN DE LOS DATOS
#
# "video_id": Conjunto de letras que cada video de Youtube tiene
#
# "trending_date": Fecha en el que el video consiguió una mayor cantidad de visitas a comparación de otros días
#
# "title": Nombre del video
#
# "channel_title": Nombre del canal de la persona que publica los videos
#
# "category_id": Categoría a la que pertenece el video(Ejemplo: 24,27,23...)
#
# "publish_time": Fecha y hora en la que se publicó el video
#
# "tags":
#
# "views": Número de ´visita que tiene el video
#
# "likes":  Número de me gusta que tiene el video
#
# "dislikes": Número de no me gusta que tiene el video
#
# "comment_count": Número de comentarios que tiene el video
#
# "thumbnail_link": Link de la imagen que contiene el video
#
# "comments_disabled": Saber si se puede o no se puede comentar en el video(TRUE,FALSE)
#
# "ratings_disabled": Saber si el contador de me gusta o no me gusta es visible(TRUE= No es visible, FALSE= Si es visible)
#
# "videos_error_or_removed": Saber si el video puede ser visible para cualquier persona(TRUE= No se puede visualizar el video, FALSE= Si se puede visualizar el video)
#
# "description": Descripción que contiene información sobre lo que trata el video
#
# "state": Estado donde se publicó el video
#
# "lat": Latitud geográfica donde se publicó el video
#
# "lon": Longitud geográfica donde se publicó el video
#
# "geometry": Registro de coordenadas de las geometrías donde se ubica el Estado dentro del planeta.

# %% [markdown]
# ## Exploración de datos

# %%
pd.set_option('display.max_rows',100)

# Mostrar todas las columnas
pd.set_option('display.max_columns',10)

# %% [markdown]
# ## CARGA DE DATOS

# %%
df
# Out:
#           video_id trending_date  \
# 0      LgVi6y5QIjM      17.14.11
# 1      Bayt7uQith4      17.14.11
# 2      1ZAPwfrtAFY      17.14.11
# 3      AHtypnRk7JE      17.14.11
# 4      ZJ9We4bjcg0      17.14.11
# ...            ...           ...
# 40835  fn5WNxy-Wcw      18.14.06
# 40836  zAFv43lxqHE      18.14.06
# 40837  zSXG5I6Y2fA      18.14.06
# 40838  5d115sePmaU      18.14.06
# 40839  go-F6xvezAM      18.14.06
#
#                                                    title  \
# 0      Sing zu Ende! | Gesangseinlagen vom Feinsten |...
# 1      Kinder ferngesteuert im Kiosk! Erwachsene abzo...
# 2      The Trump Presidency: Last Week Tonight with J...
# 3                                    Das Fermi-Paradoxon
# 4               18 SONGS mit Kelly MissesVlog (Sing-off)
# ...                                                  ...
# 40835  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
# 40836                                     YMS: The Visit
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40840 entries, 0 to 40839
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40840 non-null  str
#  1   trending_date           40840 non-null  str
#  2   title                   40840 non-null  str
#  3   channel_title           40840 non-null  str
#  4   category_id             40840 non-null  int64
#  5   publish_time            40840 non-null  str
#  6   tags                    40840 non-null  str
#  7   views                   40840 non-null  int64
#  8   likes                   40840 non-null  int64
#  9   dislikes                40840 non-null  int64
#  10  comment_count           40840 non-null  int64
#  11  thumbnail_link          40840 non-null  str
#  12  comments_disabled       40840 non-null  bool
#  13  ratings_disabled        40840 non-null  bool
#  14  video_error_or_removed  40840 non-null  bool
# ...

# %% [markdown]
# ## INSPECCIÓN DE DATOS
#
# "video_id": string
#
# "trending_date": string
#
# "title": string
#
# "channel_title": string
#
# "category_id": integer
#
# "publish_time": string
#
# "tags": string
#
# "views": integer
#
# "likes":  integer
#
# "dislikes":integer
#
# "comment_count": integer
#
# "thumbnail_link": string
#
# "comments_disabled": boolean
#
# "ratings_disabled": boolean
#
# "videos_error_or_removed": boolean
#
# "description": string
#
# "state": string
#
# "lat": float
#
# "lon": float
#
# "geometry": string

# %% [markdown]
# ## VERIFICAR LA CALIDAD DE DATOS
#
# Debemos encontrar filas que tienen valores nulos

# %%
filas_son_nulas = df[df.isnull().any(axis=1)]  # Con esto accedemos a las filas que tengan algún valor nulo en algunas de sus columnas

filas_son_nulas
# Out:
#           video_id trending_date  \
# 67     XEY-mcrPAjI      17.14.11
# 145    OA0vhAKUD0g      17.14.11
# 171    giUivdCbg0g      17.14.11
# 175    AT76sOaT8Zk      17.14.11
# 254    R2ftFltzomA      17.15.11
# ...            ...           ...
# 40718  ZX1OmtsOEm4      18.14.06
# 40745  r5sOlv58s_k      18.14.06
# 40753  b9-AsfPeohg      18.14.06
# 40811  OqjwJ3EY1V4      18.14.06
# 40812  -FO9-XfQyMU      18.14.06
#
#                                                    title  \
# 67                    Hayattta Her Şey Var 13 Kasım 2017
# 145              Outlander S03E09 i'm melting with you''
# 171    شاهد بالفيديو الهزة الارضية في داخل استديو قنا...
# 175    คุยเเซ่บShow : เปิดใจ ลูก เมีย โจ บอยสเก๊าท์ ค...
# 254    Kim wird von Jacky psychisch zerstört! | Berli...
# ...                                                  ...
# 40718             Talat Bulut hakkında korkunç iddialar!
# 40745  180613 JIMIN & JUNGKOOK - 'Black Or White' Mic...
# ...

# %% [markdown]
# Luego, hay que encontrar la cantidad total de filas con valores nulos

# %%
print(df.isnull().sum().sum()) # Total de valores nulos
# Out:
# 1552

# %% [markdown]
# Encontrar la cantidad total de filas con valores nulos

# %%
print(df.isnull().sum()) # Total de valores nulos por columna
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1552
# state                        0
# lat                          0
# lon                          0
# geometry                     0
# dtype: int64

# %% [markdown]
# Con esto podemos darnos cuenta de que la mayoría de valores nulos se encuentra en la columna "description"

# %% [markdown]
# ## PREPARACIÓN DE LOS DATOS
#
# Tomando en cuenta que un video puede NO tener una descripción, cambiaremos sus valores nulos a un valor "sin descripcion"

# %%
df['description'] = df['description'].fillna("Sin descripcion")

print(df.isnull().sum())
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# state                     0
# lat                       0
# lon                       0
# geometry                  0
# dtype: int64
